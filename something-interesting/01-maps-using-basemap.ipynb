# %% [markdown]
# # 使用 basemap 画地图

# %% [markdown]
# ## 安装依赖包
# `matplotlib、Python、numpy、proj、geos`
# [Microsoft Visual C++ 9.0](http://aka.ms/vcpython27)
# ```
# !pip2 install proj
# !pip2 install geos
# ```
# * `Matplotlib Basemap` 官网：https://matplotlib.org/basemap/
# * `Python`各种包的下载地址：https://www.lfd.uci.edu/~gohlke/pythonlibs/ ，下载对应的版本，网速慢的的同学的福利
# * 记住最后安装basemap包，这样就不会出错

# %% [markdown]
# ## 安装时遇到的问题

# %% [markdown]
# ![](https://raw.githubusercontent.com/ds19991999/githubimg/master/picgo/20180724200237.png)

# %% [markdown]
# ## 简单的例子

# %%
# %matplotlib inline

from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
# lon_0 is central longitude of projection.
# resolution = 'c' means use crude resolution coastlines.
f = plt.figure(figsize=(16,9))
m = Basemap(projection='robin',lon_0=0,resolution='c')
m.shadedrelief(scale=0.2)
plt.title("Robinson Projection")
plt.show()

# %%
# 美国宇航局的“蓝色大理石”图像
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
f = plt.figure(figsize=(10,6))
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
m.bluemarble()
plt.show()
