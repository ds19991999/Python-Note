# %% [markdown]
# # Pyplot 教程

# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Matplotlib-简介" data-toc-modified-id="Matplotlib-简介-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Matplotlib 简介</a></span></li><li><span><a href="#使用-Pyplot" data-toc-modified-id="使用-Pyplot-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>使用 Pyplot</a></span><ul class="toc-item"><li><span><a href="#plt.show()" data-toc-modified-id="plt.show()-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>plt.show()</a></span></li><li><span><a href="#plt.plot()" data-toc-modified-id="plt.plot()-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>plt.plot()</a></span><ul class="toc-item"><li><span><a href="#基本用法" data-toc-modified-id="基本用法-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>基本用法</a></span></li><li><span><a href="#字符参数" data-toc-modified-id="字符参数-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>字符参数</a></span></li><li><span><a href="#显示范围" data-toc-modified-id="显示范围-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>显示范围</a></span></li><li><span><a href="#传入Numpy数组" data-toc-modified-id="传入Numpy数组-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>传入Numpy数组</a></span></li><li><span><a href="#线条属性" data-toc-modified-id="线条属性-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>线条属性</a></span></li><li><span><a href="#使用-plt.plot()-的返回值来设置线条属性" data-toc-modified-id="使用-plt.plot()-的返回值来设置线条属性-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>使用 plt.plot() 的返回值来设置线条属性</a></span></li><li><span><a href="#plt.setp()-修改线条性质" data-toc-modified-id="plt.setp()-修改线条性质-2.2.7"><span class="toc-item-num">2.2.7&nbsp;&nbsp;</span>plt.setp() 修改线条性质</a></span></li></ul></li></ul></li><li><span><a href="#子图" data-toc-modified-id="子图-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>子图</a></span></li><li><span><a href="#图形上加上文字" data-toc-modified-id="图形上加上文字-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>图形上加上文字</a></span></li></ul></div>

# %% [markdown]
# ## Matplotlib 简介

# %% [markdown]
# matplotlib 是一个 Python 的 2D 图形包。
#
# 在线文档：http://matplotlib.org ，提供了 [Example](https://matplotlib.org/examples/index.html)、[FAQ](https://matplotlib.org/faq/index.html)、[API](https://matplotlib.org/contents.html)、[Gallery](https://matplotlib.org/gallery.html)，其中 [Gallery](https://matplotlib.org/gallery.html) 是很有用的一个部分，因为它提供了各种画图方式的可视化，方便用户根据需求进行选择。

# %% [markdown]
# ## 使用 Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### plt.show()

# %% [markdown]
# * 在 `ipython` 命令行中，我们可以使用 `magic` 命令将它插入 `notebook` 中，并且不需要调用 `plt.show()` 也可以显示：
#
# ```ipython
# %matplotlib notebook
# %matplotlib inline
# ```
# * 实际写程序中，我们还是需要调用 `plt.show()` 函数将图像显示出来。

# %% [markdown]
# ### plt.plot()

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
# Out:
# Text(0,0.5,'some numbers')

# %% [markdown]
# #### 基本用法

# %% [markdown]
# * 默认参数:`plt.plot(x,y)`
# * 指定参数:`plt.plot(x,y, format_str)`
# * 默认参数，`x 为 0~N-1`:`plt.plot(y)`
# * 指定参数，`x 为 0~N-1`:`plt.plot(y, format_str)`

# %%
plt.plot([1,2,3,4], [1,4,9,16])

# %% [markdown]
# #### 字符参数

# %% [markdown]
# 和 $MATLAB$ 中类似，我们还可以用字符来指定绘图的格式：
#
# 表示颜色的字符参数:
#
# 字符|颜色
# ----|----
# ‘b’|	蓝色，blue
# ‘g’|	绿色，green
# ‘r’|	红色，red
# ‘c’|	青色，cyan
# ‘m’|	品红，magenta
# ‘y’|	黄色，yellow
# ‘k’|	黑色，black
# ‘w’|	白色，white
#
# 表示类型的字符参数：
#
# 字符	|类型|	字符|	类型
# ----|----|-----|------
# '-'	|实线	|'--'|	虚线
# '-.'|	虚点线	|':'	点线
# '.'	|点	|','|	像素点
# 'o'	|圆点	|'v'	|下三角点
# '^'	|上三角点	|'<'|	左三角点
# '>'	|右三角点	|'1'	|下三叉点
# '2'	|上三叉点	|'3'	|左三叉点
# '4'	|右三叉点	|'s'	|正方点
# 'p'	|五角点	|'*'	|星形点
# 'h'	|六边形点1	|'H'	|六边形点2
# '+'	|加号点	|'x'	|乘号点
# 'D'	|实心菱形点	|'d'|	瘦菱形点
# '_'	|横线点

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.show()

# %% [markdown]
# #### 显示范围

# %% [markdown]
# `axis` 函数指定坐标轴显示的范围：
# ```python
# plt.axis([xmin, xmax, ymin, ymax])
# ```

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
# 指定 x 轴显示区域为 0-6，y 轴为 0-20
plt.axis([0,6,0,20])
plt.show()

# %% [markdown]
# #### 传入Numpy数组

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
# 将多个数组放在同一个plot函数中可以在同一张图中画
plt.plot(t, t, 'r--', 
         t, t**2, 'bs', 
         t, t**3, 'g^')

plt.show()

# %% [markdown]
# #### 线条属性

# %%
# 通过关键词来改变线条的性质 
# linwidth 可以改变线条的宽度，color 可以改变线条的颜色：
x = np.linspace(-np.pi,np.pi)
y = np.sin(x)

plt.plot(x, y, linewidth=2.0, color='r')

plt.show()

# %% [markdown]
# #### 使用 plt.plot() 的返回值来设置线条属性

# %% [markdown]
# plot 函数返回一个 Line2D 对象组成的列表，每个对象代表输入的一对组合，例如：
#
# * line1, line2 为两个 Line2D 对象
#
# `line1, line2 = plt.plot(x1, y1, x2, y2)`
#
# * 返回 3 个 Line2D 对象组成的**列表**
#
# `lines = plt.plot(x1, y1, x2, y2, x3, y3)`

# %%
y
# Out:
# array([-1.22464680e-16, -1.27877162e-01, -2.53654584e-01, -3.75267005e-01,
#        -4.90717552e-01, -5.98110530e-01, -6.95682551e-01, -7.81831482e-01,
#        -8.55142763e-01, -9.14412623e-01, -9.58667853e-01, -9.87181783e-01,
#        -9.99486216e-01, -9.95379113e-01, -9.74927912e-01, -9.38468422e-01,
#        -8.86599306e-01, -8.20172255e-01, -7.40277997e-01, -6.48228395e-01,
#        -5.45534901e-01, -4.33883739e-01, -3.15108218e-01, -1.91158629e-01,
#        -6.40702200e-02,  6.40702200e-02,  1.91158629e-01,  3.15108218e-01,
#         4.33883739e-01,  5.45534901e-01,  6.48228395e-01,  7.40277997e-01,
#         8.20172255e-01,  8.86599306e-01,  9.38468422e-01,  9.74927912e-01,
#         9.95379113e-01,  9.99486216e-01,  9.87181783e-01,  9.58667853e-01,
#         9.14412623e-01,  8.55142763e-01,  7.81831482e-01,  6.95682551e-01,
#         5.98110530e-01,  4.90717552e-01,  3.75267005e-01,  2.53654584e-01,
#         1.27877162e-01,  1.22464680e-16])

# %%
# 加逗号 line 中得到的是 line2D 对象
# 不加逗号得到的是只有一个 line2D 对象的列表
line, = plt.plot(x, y, 'r-')

# 将抗锯齿关闭
line.set_antialiased(False)

plt.show()

# %% [markdown]
# #### plt.setp() 修改线条性质

# %%
# 使用 plt 的 setp函数
lines = plt.plot(x, y)
# 使用键值对
plt.setp(lines, color='r', linewidth=2.0)

# 或者使用 MATLAB 风格的字符串对
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)

plt.show()

# %%
plt.setp(lines)
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: bool
#   antialiased or aa: bool
#   clip_box: a `.Bbox` instance
#   clip_on: bool
#   clip_path: [(`~matplotlib.path.Path`, `.Transform`) | `.Patch` | None]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' | 'steps-post']
#   figure: a `.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: object
#   linestyle or ls: ['solid' | 'dashed', 'dashdot', 'dotted' | (offset, on-off-dash-seq) | ``'-'`` | ``'--'`` | ``'-.'`` | ``':'`` | ``'None'`` | ``' '`` | ``''``]
#   linewidth or lw: float value in points
# ...

# %% [markdown]
# ## 子图

# %% [markdown]
# `figure()` 函数会产生一个指定编号为 `num` 的图
# ```ipython
# plt.figure(num)
# ```
# 这里，`figure(1)` 其实是可以省略的，因为默认情况下 plt 会自动产生一幅图像。
#
# 使用 `subplot` 可以在一副图中生成多个子图，其参数为：
#
# ```python
# # 行、列、图编号
# plt.subplot(numrows, numcols, fignum)
# ```
# 当 `numrows * numcols < 10` 时，中间的逗号可以省略，因此 `plt.subplot(211)` 就相当于 `plt.subplot(2,1,1)`。

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)

plt.subplot(211)
plt.plot(t1, f(t1), 'ro', t2, f(t2), 'k-')
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.show()

# %% [markdown]
# ## 图形上加上文字

# %%
# plt.hist()画直方图
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)

# 文本描述
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
# 指定位置放入文字
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
# Out:
# d:\python\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

# 使用 annotate 函数进行注释：
#     1.xy ：注释位置
#     2.xytext ：注释文字位置
plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             # 注释文字属性
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()
